# %% [markdown]
# This is how to use GitBash to transfer files from the local folder to JASMIN (without having to drag and drop)

# %% [markdown]
# If your identity isn't yet added, add it like this:

# %%
ssh-add ~/.ssh/id_ecdsa_jasmin # this is the file path to the ssh key
Enter passphrase for /c/Users/sopgra/.ssh/id_ecdsa_jasmin

# %% [markdown]
# The passphrase is 12345

# %% [markdown]
# 1) log in:

# %%
ssh -A sophiag@login.jasmin.ac.uk
Enter passphrase for key '/c/Users/sopgra/.ssh/id_ecdsa_jasmin': 12345

# %% [markdown]
# 2) check the directory using the classic ls, pwd etc.

# %% [markdown]
# 3. Transfer the data using the secure copy of a repository scp -r command

# %%
scp -r source_parent_folder1/source_parent_folder2/desired_folder sophiag@xfer-vm-01.jasmin.ac.uk:destination_parent_folder1/destination_parent_folder2 etc.

# %%
$ scp -r blended_data/meta sophiag@xfer-vm-01.jasmin.ac.uk:UKCEH/data/blended_data/meta^C

# %% [markdown]
# To re-set or re-start, use:

# %%
exit
