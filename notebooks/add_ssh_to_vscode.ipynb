# %% [markdown]
# 1) Remote explorer
# 2) Remotes (tunnels/ssh)
# 3) ssh
# 4) +
# 5) ssh hello@microsoft.com -A (e.g. -A sophiag@login.jasmin.ac.uk)
#     whatever it is can be foundon the computer's documentation
# 6) enter the passkey (12345)
